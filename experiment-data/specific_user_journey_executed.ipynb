# %% [markdown]
# # Specific User Journey Analysis
#
# This notebook analyzes the purchase journey for a specific user ID: `e2eb1291-5fec-45e6-bded-3018f0d67d66`. It leverages the same methods and data processing as the main purchase journey analysis notebook.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from datetime import datetime

# Load the dataset
df = pd.read_csv('analytics.csv')

# Set the same colors as in the original notebook for consistency
colors = ['salmon', '#F899F3', '#73FABD', '#6ED1F8','#E0F26D', '#106ED3']
facecolor = '#F5F5F5'

# Define the user ID we're interested in
TARGET_USER_ID = 'e2eb1291-5fec-45e6-bded-3018f0d67d66'

# %%
# Clean the data and filter relevant entries - same as in purchase_journey_analysis
# Remove entries without user_id or with placeholder user_ids
df_filtered = df[(df['user_id'] != 'none') & (df['user_id'] != 'less-website')].copy()

# Convert timestamp strings to datetime objects
df_filtered['timestamp'] = pd.to_datetime(df_filtered['created_at'], format='ISO8601')

# Define purchase event indicators
purchase_event_types = ['enforce_wait_modal_shown']

# Function to check if an event type indicates a purchase
def is_purchase_event(event_type):
    # Check for exact matches
    if event_type in purchase_event_types:
        return True
    
    # Check for partial matches in case the naming convention varies
    for purchase_type in purchase_event_types:
        if purchase_type.lower() in event_type.lower():
            return True
    
    return False

# Add a column to identify purchase events
df_filtered['is_purchase'] = df_filtered['type'].apply(is_purchase_event)

# Define the other event types we're interested in
df_filtered['is_add_to_cart'] = df_filtered['type'] == 'add-to-cart'
df_filtered['is_checkout'] = df_filtered['type'] == 'checkout'

# %%
# Process sessions - same as in purchase_journey_analysis
session_groups = df_filtered.groupby('session_id')

# Extract session start times, end times, duration, and whether each session contains a purchase
session_data = []
for session_id, session_df in session_groups:
    # Skip sessions with invalid or placeholder IDs
    if session_id == 'none' or pd.isna(session_id):
        continue
        
    # Sort session events by timestamp
    session_df = session_df.sort_values('timestamp')
    
    # Get user_id (assuming it's consistent within a session)
    user_id = session_df['user_id'].iloc[0] if not session_df.empty else None
    
    # Get session start and end times
    start_time = session_df['timestamp'].min()
    end_time = session_df['timestamp'].max()
    
    # Calculate session duration in minutes
    duration_minutes = (end_time - start_time).total_seconds() / 60
    
    # Check for each event type - ensuring uniqueness per session by using .any()
    has_add_to_cart = session_df['is_add_to_cart'].any()
    has_checkout = session_df['is_checkout'].any()
    has_purchase = session_df['is_purchase'].any()
    
    # Find timestamps for FIRST occurrence of each event type
    add_to_cart_time = session_df[session_df['is_add_to_cart']]['timestamp'].min() if has_add_to_cart else None
    checkout_time = session_df[session_df['is_checkout']]['timestamp'].min() if has_checkout else None
    purchase_time = session_df[session_df['is_purchase']]['timestamp'].min() if has_purchase else None
    
    # Determine event sequence order based on first occurrences
    event_order = []
    if has_add_to_cart:
        event_order.append(('add_to_cart', add_to_cart_time))
    if has_checkout:
        event_order.append(('checkout', checkout_time))
    if has_purchase:
        event_order.append(('purchase', purchase_time))
    
    # Sort events by timestamp
    event_order.sort(key=lambda x: x[1])
    
    # Extract the ordered sequence of event types
    event_sequence = [event[0] for event in event_order]
    event_sequence_str = ' → '.join(event_sequence) if event_sequence else 'no_events'
    
    # Collect relevant session details
    session_data.append({
        'session_id': session_id,
        'user_id': user_id,
        'start_time': start_time,
        'end_time': end_time,
        'duration_minutes': duration_minutes,
        'has_add_to_cart': has_add_to_cart,
        'has_checkout': has_checkout,
        'has_purchase': has_purchase,
        'event_sequence': event_sequence_str,
        'event_count': len(session_df),
        'domain': session_df['domain'].iloc[0] if 'domain' in session_df.columns and not session_df.empty else 'unknown'
    })

# Create DataFrame from collected session data
sessions_df = pd.DataFrame(session_data)

# Add flow categorization
def categorize_flow(row):
    # Complete flow
    if row['has_add_to_cart'] and row['has_checkout'] and row['has_purchase']:
        return 'Complete Flow'
    
    # Add to cart then checkout
    elif row['has_add_to_cart'] and row['has_checkout'] and not row['has_purchase']:
        return 'Add-to-Cart then Checkout'
    
    # Checkout then purchase
    elif not row['has_add_to_cart'] and row['has_checkout'] and row['has_purchase']:
        return 'Checkout then Purchase'
    
    # Just add to cart
    elif row['has_add_to_cart'] and not row['has_checkout'] and not row['has_purchase']:
        return 'Add-to-Cart'
    
    # Just checkout
    elif not row['has_add_to_cart'] and row['has_checkout'] and not row['has_purchase']:
        return 'Checkout'
    
    # Just purchase (unusual but possible)
    elif not row['has_add_to_cart'] and not row['has_checkout'] and row['has_purchase']:
        return 'Direct Purchase'
    
    # Just looking
    else:
        return 'Just Looking'

# Apply the flow categorization
sessions_df['flow_category'] = sessions_df.apply(categorize_flow, axis=1)

# Add the simpler categorization as well
def categorize_session(row):
    if not row['has_purchase']:
        return 'Just Looking'
    elif row['duration_minutes'] >= 20:
        return 'Looking Then Purchasing'
    else:
        return 'Quick Purchase'

sessions_df['category'] = sessions_df.apply(categorize_session, axis=1)

# Check if our target user exists in the data
if TARGET_USER_ID in sessions_df['user_id'].values:
    print(f"User {TARGET_USER_ID} found in the dataset!")
    
    # Get basic statistics for this user
    user_sessions = sessions_df[sessions_df['user_id'] == TARGET_USER_ID]
    print(f"Total sessions for this user: {len(user_sessions)}")
    print(f"Sessions with purchases: {user_sessions['has_purchase'].sum()}")
    
    # Display a summary of the user's sessions
    print("\nSummary of user's sessions:")
    print(user_sessions[['session_id', 'start_time', 'duration_minutes', 'flow_category', 'has_purchase']].sort_values('start_time'))
else:
    print(f"User {TARGET_USER_ID} not found in the dataset.")
# Out:
# User e2eb1291-5fec-45e6-bded-3018f0d67d66 found in the dataset!
# Total sessions for this user: 5
# Sessions with purchases: 2
#
# Summary of user's sessions:
#                                session_id                       start_time  \
# 125  b18a1f97-4630-4a17-90a4-f009b7bbed96 2025-04-30 21:06:02.587000+00:00
# 173  fb605d76-2994-43de-b833-b1aa234dfefa 2025-05-05 02:20:40.020000+00:00
# 151  e404b458-5433-4acc-800b-70c85347e4c8 2025-05-08 11:11:18.088000+00:00
# 42   362bb0d3-4848-40cd-bdc1-60360897d06b 2025-05-08 23:13:22.038000+00:00
# 94   82e7ad72-c699-44b1-9e52-6a246fbf03e4 2025-05-11 18:22:13.224000+00:00
#
#      duration_minutes           flow_category  has_purchase
# 125         34.885050            Just Looking         False
# 173          0.000000            Just Looking         False
# 151         10.741733  Checkout then Purchase          True
# 42          29.254617           Complete Flow          True
# 94           0.000000            Just Looking         False

# %%
# For our target user, analyze the purchase journey
if TARGET_USER_ID in sessions_df['user_id'].values:
    user_sessions = sessions_df[sessions_df['user_id'] == TARGET_USER_ID].sort_values('start_time')
    
    # Find the first purchase session (if any)
    purchase_sessions = user_sessions[user_sessions['has_purchase']]
    
    if not purchase_sessions.empty:
        first_purchase_session = purchase_sessions.iloc[0]
        purchase_time = first_purchase_session['start_time']
        
        print(f"First purchase session found on: {purchase_time}")
        print(f"Purchase flow category: {first_purchase_session['flow_category']}")
        
        # Get all sessions before the first purchase
        pre_purchase_sessions = user_sessions[user_sessions['start_time'] < purchase_time]
        
        print(f"\nNumber of sessions before first purchase: {len(pre_purchase_sessions)}")
        if len(pre_purchase_sessions) > 0:
            days_to_purchase = (purchase_time - user_sessions['start_time'].min()).total_seconds() / (60*60*24)
            print(f"Days from first session to first purchase: {days_to_purchase:.2f}")
            
            # Count pre-purchase session types
            pre_purchase_just_looking = sum(1 for _, row in pre_purchase_sessions.iterrows() if row['flow_category'] == 'Just Looking')
            pre_purchase_add_to_cart = sum(1 for _, row in pre_purchase_sessions.iterrows() if 'Add-to-Cart' in row['flow_category'])
            pre_purchase_checkout = sum(1 for _, row in pre_purchase_sessions.iterrows() if 'Checkout' in row['flow_category'])
            
            print(f"Just Looking sessions: {pre_purchase_just_looking}")
            print(f"Add to Cart sessions: {pre_purchase_add_to_cart}")
            print(f"Checkout sessions: {pre_purchase_checkout}")
            
            # Create a comprehensive journey object for visualization
            journey_data = {
                'user_id': TARGET_USER_ID,
                'total_sessions_before_purchase': len(pre_purchase_sessions),
                'days_to_first_purchase': days_to_purchase,
                'first_purchase_session_id': first_purchase_session['session_id'],
                'first_purchase_category': first_purchase_session['category'],
                'first_purchase_flow': first_purchase_session['flow_category'],
                'pre_purchase_session_categories': pre_purchase_sessions['category'].tolist() if not pre_purchase_sessions.empty else [],
                'pre_purchase_flow_categories': pre_purchase_sessions['flow_category'].tolist() if not pre_purchase_sessions.empty else [],
                'pre_purchase_just_looking_count': pre_purchase_just_looking,
                'pre_purchase_add_to_cart_count': pre_purchase_add_to_cart,
                'pre_purchase_checkout_count': pre_purchase_checkout
            }
        else:
            print("User purchased in their first session (no pre-purchase sessions)")
            
            # Create a minimal journey object for first-time purchasers
            journey_data = {
                'user_id': TARGET_USER_ID,
                'total_sessions_before_purchase': 0,
                'days_to_first_purchase': 0,
                'first_purchase_session_id': first_purchase_session['session_id'],
                'first_purchase_category': first_purchase_session['category'],
                'first_purchase_flow': first_purchase_session['flow_category'],
                'pre_purchase_session_categories': [],
                'pre_purchase_flow_categories': [],
                'pre_purchase_just_looking_count': 0,
                'pre_purchase_add_to_cart_count': 0,
                'pre_purchase_checkout_count': 0
            }
    else:
        print("No purchase sessions found for this user.")
else:
    print(f"User {TARGET_USER_ID} not found in the dataset.")
# Out:
# First purchase session found on: 2025-05-08 11:11:18.088000+00:00
# Purchase flow category: Checkout then Purchase
#
# Number of sessions before first purchase: 2
# Days from first session to first purchase: 7.59
# Just Looking sessions: 2
# Add to Cart sessions: 0
# Checkout sessions: 0

# %%
# Visualize the user's journey
if TARGET_USER_ID in sessions_df['user_id'].values:
    user_sessions = sessions_df[sessions_df['user_id'] == TARGET_USER_ID].sort_values('start_time')
    
    # Find purchase sessions
    purchase_sessions = user_sessions[user_sessions['has_purchase']]
    
    if not purchase_sessions.empty:
        # Prepare data for visualization
        timeline_data = []
        for _, session in user_sessions.iterrows():
            # No longer skipping very short sessions - we'll visualize them with dots on the timeline
            
            # Calculate time from first session
            time_from_first = (session['start_time'] - user_sessions['start_time'].min()).total_seconds() / (60*60*24)
            
            # Flag for very short sessions (less than 10 seconds)
            is_very_short = session['duration_minutes'] < (10 / 60)
            
            # Determine session type color and marker
            if session['has_purchase']:
                color = colors[4]  # Purchase event
                marker = 'o'
                size = 150
                zorder = 10
            elif 'Add-to-Cart' in session['flow_category'] and 'Checkout' in session['flow_category']:
                color = colors[3]  # Add to cart + checkout
                marker = 's'
                size = 120
                zorder = 8
            elif 'Add-to-Cart' in session['flow_category']:
                color = colors[2]  # Add to cart
                marker = 'D'
                size = 100
                zorder = 6
            elif 'Checkout' in session['flow_category']:
                color = colors[1]  # Checkout
                marker = '^'
                size = 100
                zorder = 7
            else:
                color = colors[0]  # Just looking
                marker = 'x'
                size = 80
                zorder = 5
                
            timeline_data.append({
                'session_id': session['session_id'],
                'time_days': time_from_first,
                'duration_minutes': session['duration_minutes'],
                'flow_category': session['flow_category'],
                'has_purchase': session['has_purchase'],
                'color': color,
                'marker': marker,
                'size': size,
                'zorder': zorder,
                'is_very_short': is_very_short,
                'domain': session['domain'] if 'domain' in session else 'unknown'
            })
        
        # Adjust x-coordinates for better spacing when events are too close
        # Sort by time
        timeline_data.sort(key=lambda x: x['time_days'])
        
        # Define minimum gap (in days) that we want between events
        min_gap = 0.75  # Minimum gap for readability
        
        # Adjust positions
        for j in range(1, len(timeline_data)):
            actual_gap = timeline_data[j]['time_days'] - timeline_data[j-1]['time_days']
            
            # If events are too close together
            if 0 < actual_gap < min_gap:
                # Shift current and all following events to maintain minimum gap
                shift = min_gap - actual_gap
                for k in range(j, len(timeline_data)):
                    timeline_data[k]['time_days'] += shift
        
        # Create the timeline visualization
        plt.figure(figsize=(14, 7), facecolor=facecolor)
        
        # Plot each session as a point
        for session in timeline_data:
            # Use different visualization for very short sessions
            if session['is_very_short']:
                plt.scatter(
                    session['time_days'], 
                    0.5,  # Fixed y-position for timeline
                    color=session['color'],
                    s=60,  # Smaller size for very short sessions
                    marker='.',  # Dot marker for very short sessions
                    zorder=session['zorder'],
                    edgecolors='black',
                    linewidth=1
                )
            else:
                plt.scatter(
                    session['time_days'], 
                    0.5,  # Fixed y-position for timeline
                    color=session['color'],
                    s=session['size'],
                    marker=session['marker'],
                    zorder=session['zorder'],
                    edgecolors='black',
                    linewidth=1
                )
            
            # Add flow category label above point with more vertical space
            # Only add text labels for sessions that aren't very short to avoid clutter
            if not session['is_very_short']:
                plt.text(
                    session['time_days'],
                    0.65,  # Increased vertical position
                    session['flow_category'],
                    rotation=45,
                    ha='center',
                    va='bottom',
                    fontsize=10,  # Slightly larger font
                    fontweight='bold' if not session['has_purchase'] else 'normal',  # Normal weight for purchase events
                    color='black',
                    bbox=dict(facecolor='white', alpha=0.7, edgecolor=session['color'], boxstyle='round,pad=0.3'),
                    zorder=session['zorder']
                )
            
            # For purchase sessions, add a "Purchase!" label at a different position so it doesn't overlap
            if session['has_purchase']:
                plt.text(
                    session['time_days'],
                    0.8,  # Higher position to avoid overlap
                    "Purchase!",
                    rotation=0,  # No rotation for better visibility
                    ha='center',
                    va='bottom',
                    fontsize=11,  # Slightly larger font for emphasis
                    fontweight='bold',
                    color='black',
                    bbox=dict(facecolor='white', alpha=0.9, edgecolor=colors[4], boxstyle='round,pad=0.3'),
                    zorder=session['zorder'] + 1  # Higher zorder to stand out
                )
            
            # Add domain information where available
            if 'domain' in session and session['domain'] != 'unknown':
                domain_text = session['domain']
                # Truncate very long domain names
                if len(domain_text) > 25:
                    domain_text = domain_text[:22] + "..."
                
                # Only add domain text for non-very-short sessions to avoid clutter
                if not session['is_very_short']:
                    plt.text(
                        session['time_days'],
                        0.95,  # Higher position for domain
                        domain_text,
                        rotation=45,
                        ha='center',
                        va='bottom',
                        fontsize=8,
                        color='darkgray',
                        bbox=dict(facecolor='white', alpha=0.5, boxstyle='round,pad=0.2'),
                        zorder=session['zorder'] - 1
                    )
            
            # Add duration label below point (only for non-very-short sessions)
            if not session['is_very_short']:
                plt.text(
                    session['time_days'],
                    0.35,  # Lower position for better spacing
                    f"{session['duration_minutes']:.1f} min",
                    ha='center',
                    va='top',
                    fontsize=9,
                    color='black',
                    bbox=dict(facecolor='white', alpha=0.7, boxstyle='round,pad=0.2'),
                    zorder=session['zorder']
                )
            # For very short sessions, add a small duration label
            else:
                seconds = session['duration_minutes'] * 60
                plt.text(
                    session['time_days'],
                    0.35,  # Lower position
                    f"{seconds:.0f}s",  # Show seconds instead of minutes
                    ha='center',
                    va='top',
                    fontsize=8,
                    color='gray',
                    zorder=session['zorder'] - 1
                )
            
            # Add time from first session as a more subtle label
            if session['time_days'] > 0.1:  # Skip for first session
                plt.text(
                    session['time_days'],
                    0.2,  # Lower position
                    f"Day {session['time_days']:.1f}",
                    ha='center',
                    va='top',
                    fontsize=8,
                    color='gray',
                    zorder=session['zorder'] - 1
                )
        
        # Connect points with lines - now dotted for better aesthetics
        times = [session['time_days'] for session in timeline_data]
        plt.plot(times, [0.5] * len(times), 'k--', alpha=0.4, zorder=1, linewidth=1.5)
        
        # Add clear markers for timeline scale
        if max(times) > 3:  # Only add markers if timeline is long enough
            day_markers = list(range(0, int(max(times)) + 2, 2))  # Every 2 days
            for day in day_markers:
                if day > 0:  # Skip day 0
                    plt.axvline(x=day, color='lightgray', linestyle=':', alpha=0.5, zorder=0)
        
        # Add annotations for first session only
        if len(timeline_data) > 0:
            plt.annotate('First Session', 
                       (timeline_data[0]['time_days'], 0.5),
                       xytext=(timeline_data[0]['time_days'], 0.25),
                       arrowprops=dict(arrowstyle='->', color='black', alpha=0.7),
                       ha='center', va='top', fontsize=10, fontweight='bold')
        
        # Set up the plot with improved aesthetics
        plt.title(f'User Journey to Purchase - User {TARGET_USER_ID}', fontsize=16)
        plt.xlabel('Days from First Session (adjusted for visibility)', fontsize=12)
        plt.yticks([])
        plt.grid(True, axis='x', alpha=0.2)
        
        # Add padding to x-axis for better appearance
        plt.xlim(left=-0.5, right=max(times) + 1.5 if times else 1)
        plt.ylim(0, 1)
        
        # Add a legend with improved positioning - now including very short sessions
        legend_elements = [
            plt.Line2D([0], [0], marker='x', color='w', markerfacecolor=colors[0], markersize=10, label='Just Looking'),
            plt.Line2D([0], [0], marker='D', color='w', markerfacecolor=colors[2], markersize=10, label='Add to Cart'),
            plt.Line2D([0], [0], marker='^', color='w', markerfacecolor=colors[1], markersize=10, label='Checkout'),
            plt.Line2D([0], [0], marker='s', color='w', markerfacecolor=colors[3], markersize=10, label='Add to Cart + Checkout'),
            plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[4], markersize=10, label='Purchase'),
            plt.Line2D([0], [0], marker='.', color='w', markerfacecolor='gray', markersize=10, label='Very Short Session (<10s)')
        ]
        plt.legend(handles=legend_elements, loc='upper right', title='Session Types')
        
        # Add journey stats
        first_purchase_session = purchase_sessions.iloc[0]
        original_days = (first_purchase_session['start_time'] - user_sessions['start_time'].min()).total_seconds() / (60*60*24)
        
        # Count very short sessions
        very_short_count = sum(1 for session in timeline_data if session['is_very_short'])
        
        stats_text = f"Total Sessions: {len(timeline_data)}\n"
        stats_text += f"Actual Days to Purchase: {original_days:.1f}\n"
        
        pre_purchase_sessions = user_sessions[user_sessions['start_time'] < first_purchase_session['start_time']]
        stats_text += f"Sessions before Purchase: {len(pre_purchase_sessions)}\n"
        
        pre_purchase_just_looking = sum(1 for _, row in pre_purchase_sessions.iterrows() if row['flow_category'] == 'Just Looking')
        pre_purchase_add_to_cart = sum(1 for _, row in pre_purchase_sessions.iterrows() if 'Add-to-Cart' in row['flow_category'])
        pre_purchase_checkout = sum(1 for _, row in pre_purchase_sessions.iterrows() if 'Checkout' in row['flow_category'])
        
        stats_text += f"Just Looking Sessions: {pre_purchase_just_looking}\n"
        stats_text += f"Add to Cart Sessions: {pre_purchase_add_to_cart}\n"
        stats_text += f"Checkout Sessions: {pre_purchase_checkout}\n"
        stats_text += f"Very Short Sessions: {very_short_count}"
        
        plt.text(0.02, 0.98, stats_text, transform=plt.gca().transAxes,
                 bbox=dict(facecolor='white', alpha=0.8, boxstyle='round,pad=0.5'),
                 va='top', ha='left', fontsize=10)
        
        # Add note about adjusted timeline
        plt.text(0.98, 0.02, "Note: Timeline spacing adjusted for readability", 
                 transform=plt.gca().transAxes,
                 va='bottom', ha='right', fontsize=8, fontstyle='italic', color='gray')
        
        plt.tight_layout()
        plt.show()
        
        # Display flow pattern as text, with purchase sessions noted
        print(f"Journey Pattern for User {TARGET_USER_ID}:")
        journey_pattern = []
        for session in timeline_data:
            prefix = "[<10s] " if session['is_very_short'] else ""
            if session['has_purchase']:
                journey_pattern.append(f"{prefix}{session['flow_category']} (Purchase!)")
            else:
                journey_pattern.append(f"{prefix}{session['flow_category']}")
        print(" → ".join(journey_pattern))
    else:
        print("No purchase sessions found for this user. Cannot visualize purchase journey.")
else:
    print(f"User {TARGET_USER_ID} not found in the dataset.")
# Out:
# /var/folders/3t/zxm5y0q90jz8w3yfmlvzj8mh0000gn/T/ipykernel_23821/3902201521.py:97: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(
# Journey Pattern for User e2eb1291-5fec-45e6-bded-3018f0d67d66:
# Just Looking → [<10s] Just Looking → Checkout then Purchase (Purchase!) → Complete Flow (Purchase!) → [<10s] Just Looking

# %%
# Let's also look at the raw event data for this user to get more details
if TARGET_USER_ID in df_filtered['user_id'].values:
    user_events = df_filtered[df_filtered['user_id'] == TARGET_USER_ID].sort_values('timestamp')
    
    print(f"Total events for user {TARGET_USER_ID}: {len(user_events)}")
    
    # Display a summary of event types
    event_type_counts = user_events['type'].value_counts()
    print("\nEvent type distribution:")
    display(event_type_counts)
    
    # Show the full sequence of events
    print("\nFull sequence of events:")
    
    # Create a more readable event log by grouping events by session
    session_events = {}
    for _, event in user_events.iterrows():
        session_id = event['session_id']
        if session_id not in session_events:
            session_events[session_id] = []
        
        # Create a readable event entry
        event_entry = {
            'timestamp': event['timestamp'],
            'type': event['type'],
            'domain': event['domain'] if 'domain' in user_events.columns else 'unknown'
        }
        session_events[session_id].append(event_entry)
    
    # Display events by session
    for i, (session_id, events) in enumerate(sorted(session_events.items(), 
                                                  key=lambda x: x[1][0]['timestamp'] if x[1] else pd.Timestamp.min)):
        session_info = sessions_df[sessions_df['session_id'] == session_id]
        if not session_info.empty:
            flow_category = session_info['flow_category'].iloc[0]
            has_purchase = session_info['has_purchase'].iloc[0]
            
            print(f"\nSession {i+1} (ID: {session_id}) - {flow_category}" + 
                  (" (Purchase Session)" if has_purchase else ""))
            
            session_start = events[0]['timestamp']
            for j, event in enumerate(events):
                time_from_start = (event['timestamp'] - session_start).total_seconds() / 60
                domain_str = f" - Domain: {event['domain']}" if event['domain'] != 'unknown' else ""
                print(f"  {j+1}. [{time_from_start:.2f} min] {event['type']}{domain_str}")
else:
    print(f"User {TARGET_USER_ID} not found in the dataset.")
# Out:
# Total events for user e2eb1291-5fec-45e6-bded-3018f0d67d66: 769
#
# Event type distribution:
# type
# time-spent                    701
# page-view                      58
# enforce_wait_modal_shown        3
# checkout                        2
# enforce_wait_info_expanded      2
# add-to-cart                     2
# enforce_wait_canceled           1
# Name: count, dtype: int64
# Full sequence of events:
#
# Session 1 (ID: b18a1f97-4630-4a17-90a4-f009b7bbed96) - Just Looking
#   1. [0.00 min] page-view - Domain: wayfair.com
#   2. [0.42 min] page-view - Domain: wayfair.com
#   3. [0.50 min] time-spent - Domain: wayfair.com
#   4. [0.58 min] time-spent - Domain: wayfair.com
#   5. [1.91 min] time-spent - Domain: wayfair.com
#   6. [2.00 min] time-spent - Domain: wayfair.com
#   7. [2.08 min] time-spent - Domain: wayfair.com
#   8. [2.16 min] time-spent - Domain: wayfair.com
#   9. [2.25 min] time-spent - Domain: wayfair.com
#   10. [2.33 min] time-spent - Domain: wayfair.com
#   11. [2.41 min] time-spent - Domain: wayfair.com
#   12. [2.50 min] time-spent - Domain: wayfair.com
#   13. [2.58 min] time-spent - Domain: wayfair.com
#   14. [2.66 min] time-spent - Domain: wayfair.com
#   15. [2.75 min] time-spent - Domain: wayfair.com
#   16. [2.83 min] time-spent - Domain: wayfair.com
#   17. [2.91 min] time-spent - Domain: wayfair.com
#   18. [3.00 min] time-spent - Domain: wayfair.com
#   19. [3.05 min] time-spent - Domain: wayfair.com
#   20. [3.07 min] page-view - Domain: wayfair.com
#   21. [3.16 min] time-spent - Domain: wayfair.com
#   22. [3.24 min] time-spent - Domain: wayfair.com
#   23. [3.32 min] time-spent - Domain: wayfair.com
#   24. [3.32 min] time-spent - Domain: wayfair.com
#   25. [3.35 min] page-view - Domain: wayfair.com
#   26. [3.43 min] time-spent - Domain: wayfair.com
#   27. [3.51 min] time-spent - Domain: wayfair.com
#   28. [3.59 min] time-spent - Domain: wayfair.com
#   29. [3.68 min] time-spent - Domain: wayfair.com
#   30. [3.76 min] time-spent - Domain: wayfair.com
#   31. [3.84 min] time-spent - Domain: wayfair.com
#   32. [3.93 min] time-spent - Domain: wayfair.com
#   33. [4.01 min] time-spent - Domain: wayfair.com
#   34. [4.09 min] time-spent - Domain: wayfair.com
#   35. [4.18 min] time-spent - Domain: wayfair.com
#   36. [4.26 min] time-spent - Domain: wayfair.com
#   37. [4.34 min] time-spent - Domain: wayfair.com
#   38. [4.43 min] time-spent - Domain: wayfair.com
#   39. [4.51 min] time-spent - Domain: wayfair.com
#   40. [4.55 min] page-view - Domain: wayfair.com
#   41. [4.63 min] time-spent - Domain: wayfair.com
#   42. [4.71 min] time-spent - Domain: wayfair.com
#   43. [4.79 min] time-spent - Domain: wayfair.com
#   44. [4.88 min] time-spent - Domain: wayfair.com
#   45. [4.96 min] time-spent - Domain: wayfair.com
#   46. [5.05 min] time-spent - Domain: wayfair.com
#   47. [5.13 min] time-spent - Domain: wayfair.com
#   48. [5.22 min] page-view - Domain: wayfair.com
#   49. [5.30 min] time-spent - Domain: wayfair.com
#   50. [5.38 min] time-spent - Domain: wayfair.com
#   51. [5.47 min] time-spent - Domain: wayfair.com
#   52. [6.02 min] page-view - Domain: wayfair.com
#   53. [6.05 min] time-spent - Domain: wayfair.com
#   54. [6.12 min] time-spent - Domain: wayfair.com
#   55. [6.22 min] time-spent - Domain: wayfair.com
#   56. [6.29 min] time-spent - Domain: wayfair.com
#   57. [6.30 min] time-spent - Domain: wayfair.com
#   58. [6.37 min] time-spent - Domain: wayfair.com
#   59. [6.38 min] time-spent - Domain: wayfair.com
#   60. [6.45 min] time-spent - Domain: wayfair.com
#   61. [6.47 min] time-spent - Domain: wayfair.com
#   62. [6.54 min] time-spent - Domain: wayfair.com
#   63. [6.55 min] time-spent - Domain: wayfair.com
#   64. [6.58 min] time-spent - Domain: wayfair.com
#   65. [6.61 min] page-view - Domain: wayfair.com
#   66. [6.62 min] time-spent - Domain: wayfair.com
#   67. [6.70 min] time-spent - Domain: wayfair.com
#   68. [6.70 min] time-spent - Domain: wayfair.com
#   69. [6.78 min] time-spent - Domain: wayfair.com
#   70. [6.79 min] time-spent - Domain: wayfair.com
#   71. [6.86 min] time-spent - Domain: wayfair.com
#   72. [6.87 min] time-spent - Domain: wayfair.com
#   73. [6.95 min] time-spent - Domain: wayfair.com
#   74. [6.95 min] time-spent - Domain: wayfair.com
#   75. [7.03 min] time-spent - Domain: wayfair.com
#   76. [7.04 min] time-spent - Domain: wayfair.com
#   77. [7.11 min] time-spent - Domain: wayfair.com
#   78. [7.12 min] time-spent - Domain: wayfair.com
#   79. [7.20 min] time-spent - Domain: wayfair.com
#   80. [7.20 min] time-spent - Domain: wayfair.com
#   81. [7.28 min] time-spent - Domain: wayfair.com
#   82. [7.29 min] time-spent - Domain: wayfair.com
#   83. [7.36 min] time-spent - Domain: wayfair.com
#   84. [7.37 min] time-spent - Domain: wayfair.com
#   85. [7.45 min] time-spent - Domain: wayfair.com
#   86. [7.45 min] time-spent - Domain: wayfair.com
#   87. [7.53 min] time-spent - Domain: wayfair.com
#   88. [7.54 min] time-spent - Domain: wayfair.com
#   89. [7.61 min] time-spent - Domain: wayfair.com
#   90. [7.62 min] time-spent - Domain: wayfair.com
#   91. [7.70 min] time-spent - Domain: wayfair.com
#   92. [7.70 min] time-spent - Domain: wayfair.com
#   93. [7.78 min] time-spent - Domain: wayfair.com
#   94. [7.79 min] time-spent - Domain: wayfair.com
#   95. [7.86 min] time-spent - Domain: wayfair.com
#   96. [7.87 min] time-spent - Domain: wayfair.com
#   97. [7.94 min] time-spent - Domain: wayfair.com
#   98. [7.95 min] time-spent - Domain: wayfair.com
#   99. [8.03 min] time-spent - Domain: wayfair.com
#   100. [8.04 min] time-spent - Domain: wayfair.com
#   101. [8.11 min] time-spent - Domain: wayfair.com
#   102. [8.12 min] time-spent - Domain: wayfair.com
#   103. [8.20 min] time-spent - Domain: wayfair.com
#   104. [8.20 min] time-spent - Domain: wayfair.com
#   105. [8.28 min] time-spent - Domain: wayfair.com
#   106. [8.29 min] time-spent - Domain: wayfair.com
#   107. [8.36 min] time-spent - Domain: wayfair.com
#   108. [8.37 min] time-spent - Domain: wayfair.com
#   109. [8.45 min] time-spent - Domain: wayfair.com
#   110. [8.45 min] time-spent - Domain: wayfair.com
#   111. [8.53 min] time-spent - Domain: wayfair.com
#   112. [8.54 min] time-spent - Domain: wayfair.com
#   113. [8.61 min] time-spent - Domain: wayfair.com
#   114. [8.62 min] time-spent - Domain: wayfair.com
#   115. [8.70 min] time-spent - Domain: wayfair.com
#   116. [8.70 min] time-spent - Domain: wayfair.com
#   117. [8.78 min] time-spent - Domain: wayfair.com
#   118. [8.79 min] time-spent - Domain: wayfair.com
#   119. [8.86 min] time-spent - Domain: wayfair.com
#   120. [8.87 min] time-spent - Domain: wayfair.com
#   121. [8.95 min] time-spent - Domain: wayfair.com
#   122. [8.95 min] time-spent - Domain: wayfair.com
#   123. [9.03 min] time-spent - Domain: wayfair.com
#   124. [9.04 min] time-spent - Domain: wayfair.com
#   125. [9.11 min] time-spent - Domain: wayfair.com
#   126. [9.12 min] time-spent - Domain: wayfair.com
#   127. [9.20 min] time-spent - Domain: wayfair.com
#   128. [9.20 min] time-spent - Domain: wayfair.com
#   129. [9.28 min] time-spent - Domain: wayfair.com
#   130. [9.29 min] time-spent - Domain: wayfair.com
#   131. [9.36 min] time-spent - Domain: wayfair.com
#   132. [9.37 min] time-spent - Domain: wayfair.com
#   133. [9.45 min] time-spent - Domain: wayfair.com
#   134. [9.45 min] time-spent - Domain: wayfair.com
#   135. [9.53 min] time-spent - Domain: wayfair.com
#   136. [9.54 min] time-spent - Domain: wayfair.com
#   137. [9.61 min] time-spent - Domain: wayfair.com
#   138. [9.62 min] time-spent - Domain: wayfair.com
#   139. [9.69 min] time-spent - Domain: wayfair.com
#   140. [9.70 min] time-spent - Domain: wayfair.com
#   141. [9.78 min] time-spent - Domain: wayfair.com
#   142. [9.79 min] time-spent - Domain: wayfair.com
#   143. [9.86 min] time-spent - Domain: wayfair.com
#   144. [9.87 min] time-spent - Domain: wayfair.com
#   145. [9.95 min] time-spent - Domain: wayfair.com
#   146. [9.95 min] time-spent - Domain: wayfair.com
#   147. [10.03 min] time-spent - Domain: wayfair.com
#   148. [10.04 min] time-spent - Domain: wayfair.com
#   149. [10.11 min] time-spent - Domain: wayfair.com
#   150. [10.12 min] time-spent - Domain: wayfair.com
#   151. [10.20 min] time-spent - Domain: wayfair.com
#   152. [10.21 min] page-view - Domain: wayfair.com
#   153. [10.29 min] time-spent - Domain: wayfair.com
#   154. [10.29 min] time-spent - Domain: wayfair.com
#   155. [10.37 min] time-spent - Domain: wayfair.com
#   156. [10.37 min] time-spent - Domain: wayfair.com
#   157. [10.45 min] time-spent - Domain: wayfair.com
#   158. [10.46 min] time-spent - Domain: wayfair.com
#   159. [10.54 min] time-spent - Domain: wayfair.com
#   160. [10.54 min] time-spent - Domain: wayfair.com
#   161. [10.62 min] time-spent - Domain: wayfair.com
#   162. [10.62 min] time-spent - Domain: wayfair.com
#   163. [10.70 min] time-spent - Domain: wayfair.com
#   164. [10.71 min] time-spent - Domain: wayfair.com
#   165. [10.79 min] time-spent - Domain: wayfair.com
#   166. [10.79 min] time-spent - Domain: wayfair.com
#   167. [10.87 min] time-spent - Domain: wayfair.com
#   168. [10.87 min] time-spent - Domain: wayfair.com
#   169. [10.95 min] time-spent - Domain: wayfair.com
#   170. [10.96 min] time-spent - Domain: wayfair.com
#   171. [11.04 min] time-spent - Domain: wayfair.com
#   172. [11.04 min] time-spent - Domain: wayfair.com
#   173. [11.12 min] time-spent - Domain: wayfair.com
#   174. [11.12 min] time-spent - Domain: wayfair.com
#   175. [11.20 min] time-spent - Domain: wayfair.com
#   176. [11.21 min] time-spent - Domain: wayfair.com
#   177. [11.29 min] time-spent - Domain: wayfair.com
#   178. [11.29 min] time-spent - Domain: wayfair.com
#   179. [11.37 min] time-spent - Domain: wayfair.com
#   180. [11.45 min] time-spent - Domain: wayfair.com
#   181. [11.54 min] time-spent - Domain: wayfair.com
#   182. [11.62 min] time-spent - Domain: wayfair.com
#   183. [11.70 min] time-spent - Domain: wayfair.com
#   184. [11.79 min] time-spent - Domain: wayfair.com
#   185. [11.79 min] time-spent - Domain: wayfair.com
#   186. [11.87 min] time-spent - Domain: wayfair.com
#   187. [11.87 min] time-spent - Domain: wayfair.com
#   188. [11.95 min] time-spent - Domain: wayfair.com
#   189. [11.96 min] time-spent - Domain: wayfair.com
#   190. [12.04 min] time-spent - Domain: wayfair.com
#   191. [12.04 min] time-spent - Domain: wayfair.com
#   192. [12.12 min] time-spent - Domain: wayfair.com
#   193. [12.20 min] time-spent - Domain: wayfair.com
#   194. [12.29 min] time-spent - Domain: wayfair.com
#   195. [12.37 min] time-spent - Domain: wayfair.com
#   196. [12.45 min] time-spent - Domain: wayfair.com
#   197. [12.53 min] time-spent - Domain: wayfair.com
#   198. [12.61 min] time-spent - Domain: wayfair.com
#   199. [12.70 min] time-spent - Domain: wayfair.com
#   200. [12.71 min] time-spent - Domain: wayfair.com
#   201. [12.74 min] page-view - Domain: wayfair.com
#   202. [12.82 min] time-spent - Domain: wayfair.com
#   203. [12.91 min] time-spent - Domain: wayfair.com
#   204. [12.99 min] time-spent - Domain: wayfair.com
#   205. [13.07 min] time-spent - Domain: wayfair.com
#   206. [13.16 min] time-spent - Domain: wayfair.com
#   207. [13.24 min] time-spent - Domain: wayfair.com
#   208. [13.32 min] time-spent - Domain: wayfair.com
#   209. [13.49 min] time-spent - Domain: wayfair.com
#   210. [13.57 min] time-spent - Domain: wayfair.com
#   211. [13.66 min] time-spent - Domain: wayfair.com
#   212. [13.74 min] time-spent - Domain: wayfair.com
#   213. [13.82 min] time-spent - Domain: wayfair.com
#   214. [13.91 min] time-spent - Domain: wayfair.com
#   215. [13.99 min] time-spent - Domain: wayfair.com
#   216. [14.07 min] time-spent - Domain: wayfair.com
#   217. [14.16 min] time-spent - Domain: wayfair.com
#   218. [14.24 min] time-spent - Domain: wayfair.com
#   219. [14.32 min] time-spent - Domain: wayfair.com
#   220. [14.41 min] time-spent - Domain: wayfair.com
#   221. [14.49 min] time-spent - Domain: wayfair.com
#   222. [14.57 min] time-spent - Domain: wayfair.com
#   223. [14.66 min] time-spent - Domain: wayfair.com
#   224. [14.74 min] time-spent - Domain: wayfair.com
#   225. [14.82 min] time-spent - Domain: wayfair.com
#   226. [14.91 min] time-spent - Domain: wayfair.com
#   227. [14.99 min] time-spent - Domain: wayfair.com
#   228. [15.07 min] time-spent - Domain: wayfair.com
#   229. [15.16 min] time-spent - Domain: wayfair.com
#   230. [15.24 min] time-spent - Domain: wayfair.com
#   231. [15.32 min] time-spent - Domain: wayfair.com
#   232. [15.41 min] time-spent - Domain: wayfair.com
#   233. [15.49 min] time-spent - Domain: wayfair.com
#   234. [15.57 min] time-spent - Domain: wayfair.com
#   235. [15.66 min] time-spent - Domain: wayfair.com
#   236. [15.74 min] time-spent - Domain: wayfair.com
#   237. [15.82 min] time-spent - Domain: wayfair.com
#   238. [15.91 min] time-spent - Domain: wayfair.com
#   239. [15.99 min] time-spent - Domain: wayfair.com
#   240. [16.05 min] page-view - Domain: wayfair.com
#   241. [16.13 min] time-spent - Domain: wayfair.com
#   242. [16.76 min] time-spent - Domain: wayfair.com
#   243. [16.79 min] time-spent - Domain: wayfair.com
#   244. [23.75 min] page-view - Domain: wayfair.com
#   245. [23.84 min] time-spent - Domain: wayfair.com
#   246. [24.09 min] time-spent - Domain: wayfair.com
#   247. [24.17 min] time-spent - Domain: wayfair.com
#   248. [24.25 min] time-spent - Domain: wayfair.com
#   249. [24.34 min] time-spent - Domain: wayfair.com
#   250. [24.42 min] time-spent - Domain: wayfair.com
#   251. [24.50 min] time-spent - Domain: wayfair.com
#   252. [24.59 min] time-spent - Domain: wayfair.com
#   253. [24.67 min] time-spent - Domain: wayfair.com
#   254. [24.75 min] time-spent - Domain: wayfair.com
#   255. [24.84 min] time-spent - Domain: wayfair.com
#   256. [25.02 min] page-view - Domain: wayfair.com
#   257. [25.69 min] time-spent - Domain: wayfair.com
#   258. [25.77 min] time-spent - Domain: wayfair.com
#   259. [25.85 min] time-spent - Domain: wayfair.com
#   260. [25.94 min] time-spent - Domain: wayfair.com
#   261. [26.02 min] time-spent - Domain: wayfair.com
#   262. [26.10 min] time-spent - Domain: wayfair.com
#   263. [26.36 min] page-view - Domain: wayfair.com
#   264. [26.68 min] time-spent - Domain: wayfair.com
#   265. [26.77 min] time-spent - Domain: wayfair.com
#   266. [26.85 min] time-spent - Domain: wayfair.com
#   267. [26.93 min] time-spent - Domain: wayfair.com
#   268. [27.02 min] time-spent - Domain: wayfair.com
#   269. [27.10 min] time-spent - Domain: wayfair.com
#   270. [27.19 min] time-spent - Domain: wayfair.com
#   271. [27.27 min] time-spent - Domain: wayfair.com
#   272. [27.35 min] time-spent - Domain: wayfair.com
#   273. [27.44 min] time-spent - Domain: wayfair.com
#   274. [28.00 min] time-spent - Domain: wayfair.com
#   275. [28.09 min] time-spent - Domain: wayfair.com
#   276. [28.17 min] time-spent - Domain: wayfair.com
#   277. [28.25 min] time-spent - Domain: wayfair.com
#   278. [28.29 min] time-spent - Domain: wayfair.com
#   279. [28.33 min] page-view - Domain: wayfair.com
#   280. [28.42 min] time-spent - Domain: wayfair.com
#   281. [28.50 min] time-spent - Domain: wayfair.com
#   282. [28.58 min] time-spent - Domain: wayfair.com
#   283. [28.67 min] time-spent - Domain: wayfair.com
#   284. [28.75 min] time-spent - Domain: wayfair.com
#   285. [28.78 min] time-spent - Domain: wayfair.com
#   286. [28.80 min] page-view - Domain: wayfair.com
#   287. [28.89 min] time-spent - Domain: wayfair.com
#   288. [28.97 min] time-spent - Domain: wayfair.com
#   289. [29.05 min] time-spent - Domain: wayfair.com
#   290. [29.05 min] time-spent - Domain: wayfair.com
#   291. [29.09 min] page-view - Domain: wayfair.com
#   292. [29.17 min] time-spent - Domain: wayfair.com
#   293. [29.21 min] page-view - Domain: wayfair.com
#   294. [31.95 min] page-view - Domain: amazon.com
#   295. [31.96 min] page-view - Domain: amazon.com
#   296. [32.01 min] page-view - Domain: amazon.com
#   297. [32.02 min] page-view - Domain: amazon.com
#   298. [32.03 min] time-spent - Domain: amazon.com
#   299. [32.05 min] time-spent - Domain: amazon.com
#   300. [32.09 min] time-spent - Domain: amazon.com
#   301. [32.10 min] time-spent - Domain: amazon.com
#   302. [32.11 min] time-spent - Domain: amazon.com
#   303. [32.14 min] time-spent - Domain: amazon.com
#   304. [32.18 min] time-spent - Domain: amazon.com
#   305. [32.19 min] time-spent - Domain: amazon.com
#   306. [32.26 min] time-spent - Domain: amazon.com
#   307. [32.27 min] time-spent - Domain: amazon.com
#   308. [32.28 min] time-spent - Domain: amazon.com
#   309. [32.30 min] time-spent - Domain: amazon.com
#   310. [32.31 min] time-spent - Domain: amazon.com
#   311. [32.31 min] time-spent - Domain: amazon.com
#   312. [32.31 min] time-spent - Domain: amazon.com
#   313. [32.31 min] time-spent - Domain: amazon.com
#   314. [32.38 min] page-view - Domain: amazon.com
#   315. [32.38 min] page-view - Domain: amazon.com
#   316. [32.42 min] page-view - Domain: amazon.com
#   317. [32.42 min] page-view - Domain: amazon.com
#   318. [32.46 min] time-spent - Domain: amazon.com
#   319. [32.47 min] time-spent - Domain: amazon.com
#   320. [32.50 min] time-spent - Domain: amazon.com
#   321. [32.52 min] time-spent - Domain: amazon.com
#   322. [32.54 min] time-spent - Domain: amazon.com
#   323. [32.55 min] time-spent - Domain: amazon.com
#   324. [32.59 min] time-spent - Domain: amazon.com
#   325. [32.60 min] time-spent - Domain: amazon.com
#   326. [32.64 min] time-spent - Domain: amazon.com
#   327. [32.67 min] time-spent - Domain: amazon.com
#   328. [32.69 min] time-spent - Domain: amazon.com
#   329. [32.72 min] time-spent - Domain: amazon.com
#   330. [32.75 min] time-spent - Domain: amazon.com
#   331. [32.77 min] time-spent - Domain: amazon.com
#   332. [32.80 min] time-spent - Domain: amazon.com
#   333. [32.84 min] time-spent - Domain: amazon.com
#   334. [32.84 min] time-spent - Domain: amazon.com
#   335. [32.88 min] time-spent - Domain: amazon.com
#   336. [32.89 min] time-spent - Domain: amazon.com
#   337. [32.92 min] time-spent - Domain: amazon.com
#   338. [32.94 min] time-spent - Domain: amazon.com
#   339. [32.96 min] time-spent - Domain: amazon.com
#   340. [32.97 min] time-spent - Domain: amazon.com
#   341. [33.00 min] time-spent - Domain: amazon.com
#   342. [33.02 min] time-spent - Domain: amazon.com
#   343. [33.04 min] time-spent - Domain: amazon.com
#   344. [33.05 min] time-spent - Domain: amazon.com
#   345. [33.09 min] time-spent - Domain: amazon.com
#   346. [33.10 min] time-spent - Domain: amazon.com
#   347. [33.13 min] time-spent - Domain: amazon.com
#   348. [33.14 min] time-spent - Domain: amazon.com
#   349. [33.17 min] time-spent - Domain: amazon.com
#   350. [33.19 min] time-spent - Domain: amazon.com
#   351. [33.21 min] time-spent - Domain: amazon.com
#   352. [33.22 min] time-spent - Domain: amazon.com
#   353. [33.25 min] time-spent - Domain: amazon.com
#   354. [33.27 min] time-spent - Domain: amazon.com
#   355. [33.29 min] time-spent - Domain: amazon.com
#   356. [33.30 min] time-spent - Domain: amazon.com
#   357. [33.34 min] time-spent - Domain: amazon.com
#   358. [33.35 min] time-spent - Domain: amazon.com
#   359. [33.38 min] time-spent - Domain: amazon.com
#   360. [33.39 min] time-spent - Domain: amazon.com
#   361. [33.42 min] time-spent - Domain: amazon.com
#   362. [33.44 min] time-spent - Domain: amazon.com
#   363. [33.46 min] time-spent - Domain: amazon.com
#   364. [33.47 min] time-spent - Domain: amazon.com
#   365. [33.50 min] time-spent - Domain: amazon.com
#   366. [33.52 min] time-spent - Domain: amazon.com
#   367. [33.54 min] time-spent - Domain: amazon.com
#   368. [33.55 min] time-spent - Domain: amazon.com
#   369. [33.59 min] time-spent - Domain: amazon.com
#   370. [33.60 min] time-spent - Domain: amazon.com
#   371. [33.63 min] time-spent - Domain: amazon.com
#   372. [33.64 min] time-spent - Domain: amazon.com
#   373. [33.67 min] time-spent - Domain: amazon.com
#   374. [33.69 min] time-spent - Domain: amazon.com
#   375. [33.71 min] time-spent - Domain: amazon.com
#   376. [33.72 min] time-spent - Domain: amazon.com
#   377. [33.75 min] time-spent - Domain: amazon.com
#   378. [33.77 min] time-spent - Domain: amazon.com
#   379. [33.79 min] time-spent - Domain: amazon.com
#   380. [33.80 min] time-spent - Domain: amazon.com
#   381. [33.84 min] time-spent - Domain: amazon.com
#   382. [33.87 min] time-spent - Domain: amazon.com
#   383. [33.88 min] time-spent - Domain: amazon.com
#   384. [33.89 min] time-spent - Domain: amazon.com
#   385. [33.92 min] time-spent - Domain: amazon.com
#   386. [33.94 min] time-spent - Domain: amazon.com
#   387. [33.97 min] time-spent - Domain: amazon.com
#   388. [34.00 min] time-spent - Domain: amazon.com
#   389. [34.02 min] time-spent - Domain: amazon.com
#   390. [34.05 min] time-spent - Domain: amazon.com
#   391. [34.09 min] time-spent - Domain: amazon.com
#   392. [34.10 min] time-spent - Domain: amazon.com
#   393. [34.14 min] time-spent - Domain: amazon.com
#   394. [34.17 min] time-spent - Domain: amazon.com
#   395. [34.19 min] time-spent - Domain: amazon.com
#   396. [34.22 min] time-spent - Domain: amazon.com
#   397. [34.25 min] time-spent - Domain: amazon.com
#   398. [34.27 min] time-spent - Domain: amazon.com
#   399. [34.30 min] time-spent - Domain: amazon.com
#   400. [34.34 min] time-spent - Domain: amazon.com
#   401. [34.35 min] time-spent - Domain: amazon.com
#   402. [34.39 min] time-spent - Domain: amazon.com
#   403. [34.42 min] time-spent - Domain: amazon.com
#   404. [34.44 min] time-spent - Domain: amazon.com
#   405. [34.47 min] time-spent - Domain: amazon.com
#   406. [34.50 min] time-spent - Domain: amazon.com
#   407. [34.52 min] time-spent - Domain: amazon.com
#   408. [34.55 min] time-spent - Domain: amazon.com
#   409. [34.59 min] time-spent - Domain: amazon.com
#   410. [34.60 min] time-spent - Domain: amazon.com
#   411. [34.64 min] time-spent - Domain: amazon.com
#   412. [34.67 min] time-spent - Domain: amazon.com
#   413. [34.69 min] time-spent - Domain: amazon.com
#   414. [34.72 min] time-spent - Domain: amazon.com
#   415. [34.75 min] time-spent - Domain: amazon.com
#   416. [34.77 min] time-spent - Domain: amazon.com
#   417. [34.80 min] time-spent - Domain: amazon.com
#   418. [34.84 min] time-spent - Domain: amazon.com
#   419. [34.85 min] time-spent - Domain: amazon.com
#   420. [34.89 min] time-spent - Domain: amazon.com
#
# Session 2 (ID: fb605d76-2994-43de-b833-b1aa234dfefa) - Just Looking
#   1. [0.00 min] page-view - Domain: amazon.com
#
# Session 3 (ID: e404b458-5433-4acc-800b-70c85347e4c8) - Checkout then Purchase (Purchase Session)
#   1. [0.00 min] page-view - Domain: shop.app
#   2. [0.01 min] time-spent - Domain: shop.app
#   3. [0.10 min] page-view - Domain: shop.app
#   4. [0.18 min] time-spent - Domain: shop.app
#   5. [0.27 min] time-spent - Domain: shop.app
#   6. [0.35 min] time-spent - Domain: shop.app
#   7. [0.48 min] page-view - Domain: shop.app
#   8. [0.57 min] time-spent - Domain: shop.app
#   9. [0.65 min] time-spent - Domain: shop.app
#   10. [0.73 min] time-spent - Domain: shop.app
#   11. [0.82 min] time-spent - Domain: shop.app
#   12. [0.90 min] time-spent - Domain: shop.app
#   13. [0.95 min] time-spent - Domain: shop.app
#   14. [1.01 min] page-view - Domain: shop.app
#   15. [1.09 min] time-spent - Domain: shop.app
#   16. [1.18 min] time-spent - Domain: shop.app
#   17. [1.26 min] time-spent - Domain: shop.app
#   18. [1.34 min] time-spent - Domain: shop.app
#   19. [1.43 min] time-spent - Domain: shop.app
#   20. [1.51 min] time-spent - Domain: shop.app
#   21. [1.59 min] time-spent - Domain: shop.app
#   22. [1.68 min] time-spent - Domain: shop.app
#   23. [1.76 min] time-spent - Domain: shop.app
#   24. [1.84 min] time-spent - Domain: shop.app
#   25. [1.93 min] time-spent - Domain: shop.app
#   26. [2.01 min] time-spent - Domain: shop.app
#   27. [2.09 min] time-spent - Domain: shop.app
#   28. [2.18 min] time-spent - Domain: shop.app
#   29. [2.26 min] time-spent - Domain: shop.app
#   30. [2.34 min] time-spent - Domain: shop.app
#   31. [2.43 min] time-spent - Domain: shop.app
#   32. [2.51 min] time-spent - Domain: shop.app
#   33. [2.51 min] time-spent - Domain: shop.app
#   34. [2.57 min] page-view - Domain: shop.app
#   35. [2.66 min] time-spent - Domain: shop.app
#   36. [2.74 min] time-spent - Domain: shop.app
#   37. [2.82 min] time-spent - Domain: shop.app
#   38. [2.91 min] time-spent - Domain: shop.app
#   39. [2.99 min] time-spent - Domain: shop.app
#   40. [3.07 min] time-spent - Domain: shop.app
#   41. [3.16 min] time-spent - Domain: shop.app
#   42. [3.24 min] time-spent - Domain: shop.app
#   43. [3.32 min] time-spent - Domain: shop.app
#   44. [3.41 min] time-spent - Domain: shop.app
#   45. [3.49 min] time-spent - Domain: shop.app
#   46. [3.57 min] time-spent - Domain: shop.app
#   47. [3.66 min] time-spent - Domain: shop.app
#   48. [3.74 min] time-spent - Domain: shop.app
#   49. [3.76 min] time-spent - Domain: shop.app
#   50. [3.80 min] checkout - Domain: shop.app
#   51. [3.80 min] page-view - Domain: shop.app
#   52. [3.88 min] time-spent - Domain: shop.app
#   53. [3.97 min] time-spent - Domain: shop.app
#   54. [4.05 min] time-spent - Domain: shop.app
#   55. [4.13 min] time-spent - Domain: shop.app
#   56. [4.22 min] time-spent - Domain: shop.app
#   57. [4.30 min] time-spent - Domain: shop.app
#   58. [4.38 min] time-spent - Domain: shop.app
#   59. [4.47 min] time-spent - Domain: shop.app
#   60. [4.55 min] time-spent - Domain: shop.app
#   61. [4.63 min] time-spent - Domain: shop.app
#   62. [4.72 min] time-spent - Domain: shop.app
#   63. [4.92 min] enforce_wait_modal_shown - Domain: shop.app
#   64. [4.97 min] time-spent - Domain: shop.app
#   65. [5.05 min] time-spent - Domain: shop.app
#   66. [5.13 min] time-spent - Domain: shop.app
#   67. [5.22 min] time-spent - Domain: shop.app
#   68. [5.30 min] time-spent - Domain: shop.app
#   69. [5.38 min] time-spent - Domain: shop.app
#   70. [5.47 min] time-spent - Domain: shop.app
#   71. [5.55 min] time-spent - Domain: shop.app
#   72. [5.57 min] enforce_wait_info_expanded - Domain: shop.app
#   73. [5.63 min] time-spent - Domain: shop.app
#   74. [5.72 min] time-spent - Domain: shop.app
#   75. [5.80 min] time-spent - Domain: shop.app
#   76. [5.81 min] enforce_wait_canceled - Domain: shop.app
#   77. [5.84 min] enforce_wait_modal_shown - Domain: shop.app
#   78. [5.88 min] time-spent - Domain: shop.app
#   79. [5.97 min] time-spent - Domain: shop.app
#   80. [6.05 min] time-spent - Domain: shop.app
#   81. [6.08 min] enforce_wait_info_expanded - Domain: shop.app
#   82. [6.13 min] time-spent - Domain: shop.app
#   83. [6.22 min] time-spent - Domain: shop.app
#   84. [6.30 min] time-spent - Domain: shop.app
#   85. [6.38 min] time-spent - Domain: shop.app
#   86. [6.38 min] time-spent - Domain: shop.app
#   87. [6.44 min] page-view - Domain: shop.app
#   88. [6.52 min] time-spent - Domain: shop.app
#   89. [6.61 min] time-spent - Domain: shop.app
#   90. [8.13 min] time-spent - Domain: shop.app
#   91. [8.17 min] time-spent - Domain: shop.app
#   92. [8.17 min] time-spent - Domain: shop.app
#   93. [8.18 min] time-spent - Domain: shop.app
#   94. [8.26 min] time-spent - Domain: shop.app
#   95. [10.44 min] page-view - Domain: shop.app
#   96. [10.53 min] time-spent - Domain: shop.app
#   97. [10.61 min] time-spent - Domain: shop.app
#   98. [10.74 min] time-spent - Domain: shop.app
#
# Session 4 (ID: 362bb0d3-4848-40cd-bdc1-60360897d06b) - Complete Flow (Purchase Session)
#   1. [0.00 min] page-view - Domain: wayfair.com
#   2. [0.08 min] time-spent - Domain: wayfair.com
#   3. [0.16 min] time-spent - Domain: wayfair.com
#   4. [0.33 min] time-spent - Domain: wayfair.com
#   5. [0.41 min] time-spent - Domain: wayfair.com
#   6. [0.50 min] time-spent - Domain: wayfair.com
#   7. [0.55 min] time-spent - Domain: wayfair.com
#   8. [0.57 min] page-view - Domain: wayfair.com
#   9. [0.65 min] time-spent - Domain: wayfair.com
#   10. [0.68 min] time-spent - Domain: wayfair.com
#   11. [0.70 min] page-view - Domain: wayfair.com
#   12. [0.79 min] time-spent - Domain: wayfair.com
#   13. [0.87 min] time-spent - Domain: wayfair.com
#   14. [0.95 min] time-spent - Domain: wayfair.com
#   15. [1.04 min] time-spent - Domain: wayfair.com
#   16. [1.12 min] time-spent - Domain: wayfair.com
#   17. [1.20 min] time-spent - Domain: wayfair.com
#   18. [1.29 min] time-spent - Domain: wayfair.com
#   19. [1.37 min] time-spent - Domain: wayfair.com
#   20. [1.45 min] time-spent - Domain: wayfair.com
#   21. [1.54 min] time-spent - Domain: wayfair.com
#   22. [1.62 min] time-spent - Domain: wayfair.com
#   23. [1.70 min] time-spent - Domain: wayfair.com
#   24. [1.79 min] time-spent - Domain: wayfair.com
#   25. [1.87 min] time-spent - Domain: wayfair.com
#   26. [1.95 min] time-spent - Domain: wayfair.com
#   27. [2.04 min] time-spent - Domain: wayfair.com
#   28. [2.12 min] time-spent - Domain: wayfair.com
#   29. [2.20 min] time-spent - Domain: wayfair.com
#   30. [2.22 min] page-view - Domain: wayfair.com
#   31. [2.29 min] time-spent - Domain: wayfair.com
#   32. [2.30 min] time-spent - Domain: wayfair.com
#   33. [2.38 min] time-spent - Domain: wayfair.com
#   34. [2.47 min] time-spent - Domain: wayfair.com
#   35. [2.55 min] time-spent - Domain: wayfair.com
#   36. [2.63 min] time-spent - Domain: wayfair.com
#   37. [2.72 min] time-spent - Domain: wayfair.com
#   38. [2.80 min] time-spent - Domain: wayfair.com
#   39. [2.88 min] time-spent - Domain: wayfair.com
#   40. [2.97 min] time-spent - Domain: wayfair.com
#   41. [3.05 min] time-spent - Domain: wayfair.com
#   42. [3.13 min] time-spent - Domain: wayfair.com
#   43. [3.22 min] time-spent - Domain: wayfair.com
#   44. [3.30 min] time-spent - Domain: wayfair.com
#   45. [3.38 min] time-spent - Domain: wayfair.com
#   46. [3.47 min] time-spent - Domain: wayfair.com
#   47. [3.55 min] time-spent - Domain: wayfair.com
#   48. [3.63 min] time-spent - Domain: wayfair.com
#   49. [3.72 min] time-spent - Domain: wayfair.com
#   50. [3.80 min] time-spent - Domain: wayfair.com
#   51. [3.88 min] time-spent - Domain: wayfair.com
#   52. [3.97 min] time-spent - Domain: wayfair.com
#   53. [4.05 min] time-spent - Domain: wayfair.com
#   54. [4.13 min] time-spent - Domain: wayfair.com
#   55. [4.22 min] time-spent - Domain: wayfair.com
#   56. [4.30 min] time-spent - Domain: wayfair.com
#   57. [4.38 min] time-spent - Domain: wayfair.com
#   58. [4.47 min] time-spent - Domain: wayfair.com
#   59. [4.55 min] time-spent - Domain: wayfair.com
#   60. [4.63 min] time-spent - Domain: wayfair.com
#   61. [4.72 min] time-spent - Domain: wayfair.com
#   62. [4.80 min] time-spent - Domain: wayfair.com
#   63. [4.88 min] time-spent - Domain: wayfair.com
#   64. [4.97 min] time-spent - Domain: wayfair.com
#   65. [5.05 min] time-spent - Domain: wayfair.com
#   66. [5.13 min] time-spent - Domain: wayfair.com
#   67. [5.22 min] time-spent - Domain: wayfair.com
#   68. [5.30 min] time-spent - Domain: wayfair.com
#   69. [5.38 min] time-spent - Domain: wayfair.com
#   70. [5.47 min] time-spent - Domain: wayfair.com
#   71. [5.55 min] time-spent - Domain: wayfair.com
#   72. [5.63 min] time-spent - Domain: wayfair.com
#   73. [5.72 min] time-spent - Domain: wayfair.com
#   74. [5.80 min] time-spent - Domain: wayfair.com
#   75. [5.88 min] time-spent - Domain: wayfair.com
#   76. [5.97 min] time-spent - Domain: wayfair.com
#   77. [6.05 min] time-spent - Domain: wayfair.com
#   78. [6.13 min] time-spent - Domain: wayfair.com
#   79. [6.22 min] time-spent - Domain: wayfair.com
#   80. [6.30 min] time-spent - Domain: wayfair.com
#   81. [6.38 min] time-spent - Domain: wayfair.com
#   82. [6.47 min] time-spent - Domain: wayfair.com
#   83. [6.55 min] time-spent - Domain: wayfair.com
#   84. [6.63 min] time-spent - Domain: wayfair.com
#   85. [6.72 min] time-spent - Domain: wayfair.com
#   86. [6.80 min] time-spent - Domain: wayfair.com
#   87. [6.88 min] time-spent - Domain: wayfair.com
#   88. [6.97 min] time-spent - Domain: wayfair.com
#   89. [7.05 min] time-spent - Domain: wayfair.com
#   90. [7.13 min] time-spent - Domain: wayfair.com
#   91. [7.22 min] time-spent - Domain: wayfair.com
#   92. [7.30 min] time-spent - Domain: wayfair.com
#   93. [7.38 min] time-spent - Domain: wayfair.com
#   94. [7.47 min] time-spent - Domain: wayfair.com
#   95. [7.55 min] time-spent - Domain: wayfair.com
#   96. [7.63 min] time-spent - Domain: wayfair.com
#   97. [7.72 min] time-spent - Domain: wayfair.com
#   98. [7.80 min] time-spent - Domain: wayfair.com
#   99. [7.88 min] time-spent - Domain: wayfair.com
#   100. [7.97 min] time-spent - Domain: wayfair.com
#   101. [8.05 min] time-spent - Domain: wayfair.com
#   102. [8.13 min] time-spent - Domain: wayfair.com
#   103. [8.22 min] time-spent - Domain: wayfair.com
#   104. [8.30 min] time-spent - Domain: wayfair.com
#   105. [8.38 min] time-spent - Domain: wayfair.com
#   106. [8.47 min] time-spent - Domain: wayfair.com
#   107. [8.55 min] time-spent - Domain: wayfair.com
#   108. [8.63 min] time-spent - Domain: wayfair.com
#   109. [8.72 min] time-spent - Domain: wayfair.com
#   110. [8.80 min] time-spent - Domain: wayfair.com
#   111. [8.88 min] time-spent - Domain: wayfair.com
#   112. [8.97 min] time-spent - Domain: wayfair.com
#   113. [9.05 min] time-spent - Domain: wayfair.com
#   114. [9.13 min] time-spent - Domain: wayfair.com
#   115. [9.22 min] time-spent - Domain: wayfair.com
#   116. [9.30 min] time-spent - Domain: wayfair.com
#   117. [9.38 min] time-spent - Domain: wayfair.com
#   118. [9.47 min] time-spent - Domain: wayfair.com
#   119. [9.55 min] time-spent - Domain: wayfair.com
#   120. [9.63 min] time-spent - Domain: wayfair.com
#   121. [9.72 min] time-spent - Domain: wayfair.com
#   122. [9.80 min] time-spent - Domain: wayfair.com
#   123. [9.88 min] time-spent - Domain: wayfair.com
#   124. [9.97 min] time-spent - Domain: wayfair.com
#   125. [10.05 min] time-spent - Domain: wayfair.com
#   126. [10.13 min] time-spent - Domain: wayfair.com
#   127. [10.22 min] time-spent - Domain: wayfair.com
#   128. [10.30 min] time-spent - Domain: wayfair.com
#   129. [10.38 min] time-spent - Domain: wayfair.com
#   130. [10.47 min] time-spent - Domain: wayfair.com
#   131. [10.55 min] time-spent - Domain: wayfair.com
#   132. [10.63 min] time-spent - Domain: wayfair.com
#   133. [10.72 min] time-spent - Domain: wayfair.com
#   134. [10.80 min] time-spent - Domain: wayfair.com
#   135. [10.88 min] time-spent - Domain: wayfair.com
#   136. [10.97 min] time-spent - Domain: wayfair.com
#   137. [11.05 min] time-spent - Domain: wayfair.com
#   138. [11.13 min] time-spent - Domain: wayfair.com
#   139. [11.22 min] time-spent - Domain: wayfair.com
#   140. [11.30 min] time-spent - Domain: wayfair.com
#   141. [11.38 min] time-spent - Domain: wayfair.com
#   142. [11.47 min] time-spent - Domain: wayfair.com
#   143. [11.55 min] time-spent - Domain: wayfair.com
#   144. [11.63 min] time-spent - Domain: wayfair.com
#   145. [11.72 min] time-spent - Domain: wayfair.com
#   146. [11.80 min] time-spent - Domain: wayfair.com
#   147. [11.88 min] time-spent - Domain: wayfair.com
#   148. [11.97 min] time-spent - Domain: wayfair.com
#   149. [12.05 min] time-spent - Domain: wayfair.com
#   150. [12.13 min] time-spent - Domain: wayfair.com
#   151. [12.22 min] time-spent - Domain: wayfair.com
#   152. [12.30 min] time-spent - Domain: wayfair.com
#   153. [12.37 min] time-spent - Domain: wayfair.com
#   154. [13.01 min] page-view - Domain: etsy.com
#   155. [13.09 min] time-spent - Domain: etsy.com
#   156. [13.18 min] time-spent - Domain: etsy.com
#   157. [13.26 min] time-spent - Domain: etsy.com
#   158. [13.43 min] time-spent - Domain: etsy.com
#   159. [13.51 min] time-spent - Domain: etsy.com
#   160. [13.59 min] time-spent - Domain: etsy.com
#   161. [13.68 min] time-spent - Domain: etsy.com
#   162. [13.73 min] time-spent - Domain: etsy.com
#   163. [13.77 min] page-view - Domain: etsy.com
#   164. [13.85 min] time-spent - Domain: etsy.com
#   165. [13.93 min] time-spent - Domain: etsy.com
#   166. [14.02 min] time-spent - Domain: etsy.com
#   167. [14.10 min] time-spent - Domain: etsy.com
#   168. [14.18 min] time-spent - Domain: etsy.com
#   169. [14.23 min] page-view - Domain: etsy.com
#   170. [14.32 min] time-spent - Domain: etsy.com
#   171. [14.38 min] time-spent - Domain: etsy.com
#   172. [14.41 min] page-view - Domain: etsy.com
#   173. [14.49 min] time-spent - Domain: etsy.com
#   174. [14.54 min] page-view - Domain: etsy.com
#   175. [14.62 min] time-spent - Domain: etsy.com
#   176. [14.71 min] time-spent - Domain: etsy.com
#   177. [14.79 min] time-spent - Domain: etsy.com
#   178. [14.87 min] time-spent - Domain: etsy.com
#   179. [14.95 min] time-spent - Domain: etsy.com
#   180. [14.96 min] time-spent - Domain: etsy.com
#   181. [15.04 min] page-view - Domain: etsy.com
#   182. [15.12 min] time-spent - Domain: etsy.com
#   183. [15.42 min] page-view - Domain: etsy.com
#   184. [15.50 min] time-spent - Domain: etsy.com
#   185. [15.58 min] time-spent - Domain: etsy.com
#   186. [15.67 min] time-spent - Domain: etsy.com
#   187. [15.78 min] page-view - Domain: etsy.com
#   188. [15.86 min] time-spent - Domain: etsy.com
#   189. [15.94 min] time-spent - Domain: etsy.com
#   190. [16.02 min] time-spent - Domain: etsy.com
#   191. [16.11 min] time-spent - Domain: etsy.com
#   192. [16.19 min] time-spent - Domain: etsy.com
#   193. [16.27 min] time-spent - Domain: etsy.com
#   194. [16.36 min] time-spent - Domain: etsy.com
#   195. [16.44 min] time-spent - Domain: etsy.com
#   196. [16.52 min] time-spent - Domain: etsy.com
#   197. [16.58 min] add-to-cart - Domain: etsy.com
#   198. [16.58 min] time-spent - Domain: etsy.com
#   199. [16.61 min] checkout - Domain: etsy.com
#   200. [16.61 min] page-view - Domain: etsy.com
#   201. [16.69 min] time-spent - Domain: etsy.com
#   202. [16.77 min] time-spent - Domain: etsy.com
#   203. [16.86 min] time-spent - Domain: etsy.com
#   204. [16.94 min] time-spent - Domain: etsy.com
#   205. [16.95 min] time-spent - Domain: etsy.com
#   206. [16.98 min] page-view - Domain: etsy.com
#   207. [17.00 min] time-spent - Domain: etsy.com
#   208. [17.04 min] page-view - Domain: etsy.com
#   209. [17.12 min] time-spent - Domain: etsy.com
#   210. [17.20 min] time-spent - Domain: etsy.com
#   211. [17.29 min] time-spent - Domain: etsy.com
#   212. [17.37 min] time-spent - Domain: etsy.com
#   213. [17.45 min] time-spent - Domain: etsy.com
#   214. [17.54 min] time-spent - Domain: etsy.com
#   215. [17.62 min] time-spent - Domain: etsy.com
#   216. [17.70 min] time-spent - Domain: etsy.com
#   217. [17.79 min] time-spent - Domain: etsy.com
#   218. [17.87 min] time-spent - Domain: etsy.com
#   219. [17.95 min] time-spent - Domain: etsy.com
#   220. [17.99 min] page-view - Domain: etsy.com
#   221. [18.07 min] time-spent - Domain: etsy.com
#   222. [18.09 min] add-to-cart - Domain: etsy.com
#   223. [18.16 min] time-spent - Domain: etsy.com
#   224. [18.18 min] time-spent - Domain: etsy.com
#   225. [18.21 min] page-view - Domain: etsy.com
#   226. [18.29 min] time-spent - Domain: etsy.com
#   227. [18.37 min] time-spent - Domain: etsy.com
#   228. [18.46 min] time-spent - Domain: etsy.com
#   229. [18.54 min] time-spent - Domain: etsy.com
#   230. [18.58 min] page-view - Domain: etsy.com
#   231. [18.96 min] time-spent - Domain: etsy.com
#   232. [18.97 min] time-spent - Domain: etsy.com
#   233. [18.99 min] page-view - Domain: etsy.com
#   234. [19.07 min] time-spent - Domain: etsy.com
#   235. [19.07 min] enforce_wait_modal_shown - Domain: etsy.com
#   236. [19.15 min] time-spent - Domain: etsy.com
#   237. [19.24 min] time-spent - Domain: etsy.com
#   238. [19.32 min] time-spent - Domain: etsy.com
#   239. [19.36 min] time-spent - Domain: etsy.com
#   240. [19.47 min] page-view - Domain: etsy.com
#   241. [19.56 min] time-spent - Domain: etsy.com
#   242. [19.60 min] time-spent - Domain: etsy.com
#   243. [19.62 min] time-spent - Domain: etsy.com
#   244. [19.63 min] time-spent - Domain: etsy.com
#   245. [19.64 min] time-spent - Domain: etsy.com
#   246. [19.70 min] time-spent - Domain: etsy.com
#   247. [20.63 min] page-view - Domain: etsy.com
#   248. [29.17 min] page-view - Domain: etsy.com
#   249. [29.25 min] time-spent - Domain: etsy.com
#
# Session 5 (ID: 82e7ad72-c699-44b1-9e52-6a246fbf03e4) - Just Looking
#   1. [0.00 min] page-view - Domain: etsy.com

# %% [markdown]
# ## User Journey Analysis Summary
#
# This notebook has analyzed the journey of user `e2eb1291-5fec-45e6-bded-3018f0d67d66`, looking at their sequence of sessions, events, and patterns leading to a purchase. The timeline visualization shows the progression of session types over time, highlighting how the user moved through different stages of the purchasing funnel.
#
# Key insights:
# 1. Whether the user had multiple sessions before making a purchase
# 2. The types of activities they engaged in during each session (browsing, adding to cart, checkout)
# 3. The time elapsed between their first interaction and their first purchase
# 4. The specific events that occurred in their purchase session
#
# This kind of individual user journey analysis complements the aggregate analysis in the main notebook by providing a more detailed look at specific behavioral patterns.
